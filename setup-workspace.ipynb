# %% [markdown]
# ## Viendo los scopes de Key Vault

# %% [markdown]
# ##a

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list("db-scope")

# %%
dbutils.secrets.get('akv-kvfinalprojecteastus001', 'password-github-mamacedo23')

# %% [markdown]
# ## Permisos en metastore

# %%
# %sql SHOW GRANTS ON METASTORE

# %%
# %sql
GRANT CREATE CATALOG ON METASTORE TO `grp_de`;
